# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv("sales_082020.csv")
sales
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# 0                Dresses               NaN      GBP   19.11  2020-08-03
# 1              Outerwear  Adidas Originals      GBP   15.92  2020-08-09
# 2            Tops - Mens               NaN      GBP    6.37  2020-08-07
# 3            Tops - Mens          Berghaus      GBP   25.27  2020-08-09
# 4       Bottoms - Womens               NaN      GBP    8.90  2020-08-09
# ...                  ...               ...      ...     ...         ...
# 237666  Bottoms - Womens               NaN      GBP   17.11  2020-08-06
# 237667              Home               NaN      USD   69.00  2020-08-05
# 237668             Other               NaN      GBP   58.28  2020-08-05
# 237669             Shoes               NaN      GBP    9.46  2020-08-05
# 237670             Other               NaN      USD  160.76  2020-08-06
#
# [237671 rows x 10 columns]

# %%
curr = pd.read_csv("currency_rates_082020_EUR.csv")
curr.head(5)
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020   1.0
# 1      EUR  8/2/2020   1.0
# 2      EUR  8/3/2020   1.0
# 3      EUR  8/4/2020   1.0
# 4      EUR  8/5/2020   1.0

# %%
curr.head()
# Out:
#   currency      date  rate
# 0      EUR  8/1/2020   1.0
# 1      EUR  8/2/2020   1.0
# 2      EUR  8/3/2020   1.0
# 3      EUR  8/4/2020   1.0
# 4      EUR  8/5/2020   1.0

# %%
sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
curr["date"]=pd.to_datetime(curr.date)
sales["date"]=pd.to_datetime(sales.date)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 18.1+ MB

# %%
curr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   currency  220 non-null    object
#  1   date      220 non-null    datetime64[ns]
#  2   rate      220 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 5.3+ KB

# %%
curr
# Out:
#     currency       date    rate
# 0        EUR 2020-08-01  1.0000
# 1        EUR 2020-08-02  1.0000
# 2        EUR 2020-08-03  1.0000
# 3        EUR 2020-08-04  1.0000
# 4        EUR 2020-08-05  1.0000
# ..       ...        ...     ...
# 215      BRL 2020-08-06  6.3324
# 216      BRL 2020-08-07  6.4111
# 217      BRL 2020-08-08  6.4111
# 218      BRL 2020-08-09  6.4111
# 219      BRL 2020-08-10  6.4351
#
# [220 rows x 3 columns]

# %%
final_df = pd.merge(sales, curr, how="inner", on=["currency", "date"])
final_df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2       pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3       j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4       kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
# ...            ...           ...       ...            ...           ...
# 237666  d7dx6f3qv7           RoW  e2p108mu            RoW  nan9a4p10ayk
# 237667  iaf2ck3rj6            IT  gjb1qntq            RoW  lxj477q1hab2
# 237668  tucgt70cwc            AU  9adnlxvr            RoW  2g0g0obhwjuc
# 237669  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 237670  wnmihth4io            GB  5yogzc17            RoW  wrgq88ujwh5d
#
#                 category             brand currency    price       date  \
# 0                Dresses               NaN      GBP    19.11 2020-08-03
# 1       Outerwear - Mens  Adidas Originals      GBP    24.91 2020-08-03
# 2          Tops - Womens               NaN      GBP    19.31 2020-08-03
# 3       Bottoms - Womens  Urban Outfitters      GBP    16.98 2020-08-03
# 4                  Other               NaN      GBP     2.85 2020-08-03
# ...                  ...               ...      ...      ...        ...
# 237666       Tops - Mens               NaN      PLN     4.24 2020-08-04
# 237667       Accessories               NaN      CZK  3923.18 2020-08-04
# 237668         Jewellery               NaN      PLN   525.82 2020-08-09
# 237669  Bottoms - Womens   Brandy Melville      BRL    34.92 2020-08-06
# 237670  Bottoms - Womens               NaN      NOK   533.06 2020-08-08
#
#             rate
# 0        0.89935
# 1        0.89935
# 2        0.89935
# 3        0.89935
# 4        0.89935
# ...          ...
# 237666   4.39693
# 237667  26.12360
# 237668   4.41427
# 237669   6.33240
# 237670  10.64540
#
# [237671 rows x 11 columns]

# %%
final_df["currency"].value_counts()
# Out:
# GBP    139478
# USD     82558
# AUD      7580
# EUR      5934
# CAD      1651
# NZD       306
# CHF        95
# SEK        25
# DKK        16
# JPY         6
# SGD         5
# PLN         5
# MXN         2
# NOK         2
# THB         1
# ILS         1
# HKD         1
# MYR         1
# TWD         1
# HUF         1
# CZK         1
# BRL         1
# Name: currency, dtype: int64

# %%
final_df["total_sales"] = final_df["price"] / final_df["rate"]

# %%
final_df["total_sales"].sum()
# Out:
# 6471510.822498876

# %% [markdown]
# 1. How many rows in the sales dataset?(Just write the numbers in the format of 000.000)

# %%
sales.shape[0]
# Out:
# 237671

# %% [markdown]
# 2. How many columns in the sales dataset?(Just write the numbers)

# %%
sales.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\federal\Desktop\Clarusway\DataScience\Python\Time Management İnterview\TimeManagement.ipynb Cell 46' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/federal/Desktop/Clarusway/DataScience/Python/Time%20Management%20%C4%B0nterview/TimeManagement.ipynb#ch0000047?line=0'>1</a> sales.shape[1]
#
# NameError: name 'sales' is not defined

# %% [markdown]
# 3. What is the total number of sellers?(Just write the numbers in the format of 000.000)

# %%
sales["seller_id"].nunique()
# Out:
# 114227

# %%
len(sales["seller_id"].unique())
# Out:
# 114227

# %%
sales.head(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\federal\Desktop\Clarusway\DataScience\Python\Time Management İnterview\TimeManagement.ipynb Cell 53' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/federal/Desktop/Clarusway/DataScience/Python/Time%20Management%20%C4%B0nterview/TimeManagement.ipynb#ch0000054?line=0'>1</a> sales.head(4)
#
# NameError: name 'sales' is not defined

# %% [markdown]
# 4. What is the total value of sales in EUR?(Just write the numbers in the format of 0.000.000 )

# %%
sales[sales["currency"] == "EUR"]["price"].sum()
# Out:
# 275837.69

# %%
sales[sales["currency"] == "EUR"][["price"]].apply(sum)
# Out:
# price    275837.69
# dtype: float64

# %% [markdown]
# 5. Which brand has the highest number of purchases during the period?(Just write down the brand as in the dataset, your answer is supposed to be case sensitive)

# %%
sales
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price       date
# 0                Dresses               NaN      GBP   19.11 2020-08-03
# 1              Outerwear  Adidas Originals      GBP   15.92 2020-08-09
# 2            Tops - Mens               NaN      GBP    6.37 2020-08-07
# 3            Tops - Mens          Berghaus      GBP   25.27 2020-08-09
# 4       Bottoms - Womens               NaN      GBP    8.90 2020-08-09
# ...                  ...               ...      ...     ...        ...
# 237666  Bottoms - Womens               NaN      GBP   17.11 2020-08-06
# 237667              Home               NaN      USD   69.00 2020-08-05
# 237668             Other               NaN      GBP   58.28 2020-08-05
# 237669             Shoes               NaN      GBP    9.46 2020-08-05
# 237670             Other               NaN      USD  160.76 2020-08-06
#
# [237671 rows x 10 columns]

# %%
sales["brand"].value_counts().head(1)
# Out:
# Nike    9575
# Name: brand, dtype: int64

# %%
sales["brand"].value_counts().nlargest(10)
# Out:
# Nike                  9575
# Brandy Melville       5065
# Topshop               4561
# PrettyLittle Thing    4136
# Adidas                3905
# American Vintage      3790
# Zara                  3003
# Urban Outfitters      2932
# ASOS                  2154
# Vans                  1998
# Name: brand, dtype: int64

# %%
sales["brand"].value_counts().nsmallest(10)
# Out:
# 3LAB                   1
# Maison Scotch          1
# Lisa Says Gah          1
# Seychelles             1
# Kimora Lee Simmons     1
# Paco                   1
# Blooming & Co.         1
# Intentionally Blank    1
# LPA                    1
# Three Floor            1
# Name: brand, dtype: int64

# %% [markdown]
# 6. How many items in the “Jewellery” category have no brand associated with them?

# %%
sales["category"].value_counts()
# Out:
# Tops - Womens        45450
# Tops - Mens          32611
# Bottoms - Womens     30001
# Shoes                21764
# Accessories          21153
# Dresses              19238
# Jewellery            14923
# Beauty                8746
# Other                 6599
# Outerwear             6321
# Bottoms - Mens        5763
# Lingerie              5301
# Outerwear - Mens      4156
# Tech                  3496
# Home                  3477
# Music                 2510
# Kids                  2135
# Art                   1777
# Books & magazines     1081
# Film                   466
# Sports equipment       413
# Underwear              177
# Transportation          90
# UNSPECIFIED              7
# Name: category, dtype: int64

# %%
a = sales[sales["category"] == "Jewellery"] 
a
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 23      94lh9gu3bu            US  dhsa2q6o             US  1m846u2l2dyl
# 48      u8da411658            AU  qn7p4cv2             AU  dd4d4p2h4us2
# 49      9exo58j839            AU  qn7p4cv2             AU  6nogqtmgfjsn
# 50      9exo58j839            AU  qn7p4cv2             AU  w5ixs8y20z3n
# 51      9exo58j839            AU  qn7p4cv2             AU  g5usn39z8b7u
# ...            ...           ...       ...            ...           ...
# 237545  rabu7nz8gn            US  rv5nmiwq             US  ikfosml5pjas
# 237568  ytjobx2wzg            GB  qib5sh0l             GB  tn00dvezdp43
# 237569  ytjobx2wzg            GB  qib5sh0l             GB  eykndnmcb4g6
# 237616  p0jol2ieus            US  4pi8qok2             US  0ipj5zmes1cu
# 237643  q86525x69t            GB  33hffrhq             GB  426jwzj6b2uz
#
#          category brand currency  price       date
# 23      Jewellery   NaN      USD  16.29 2020-08-03
# 48      Jewellery   NaN      AUD  12.52 2020-08-07
# 49      Jewellery   NaN      AUD   8.48 2020-08-09
# 50      Jewellery   NaN      AUD   5.58 2020-08-09
# 51      Jewellery   NaN      AUD   5.37 2020-08-09
# ...           ...   ...      ...    ...        ...
# 237545  Jewellery   NaN      USD  21.19 2020-08-05
# 237568  Jewellery   NaN      GBP   1.15 2020-08-05
# 237569  Jewellery   NaN      GBP   1.15 2020-08-05
# 237616  Jewellery   NaN      USD  18.67 2020-08-08
# 237643  Jewellery   NaN      GBP   5.30 2020-08-05
#
# [14923 rows x 10 columns]

# %%
a.brand.isnull()
# Out:
# 23        True
# 48        True
# 49        True
# 50        True
# 51        True
#           ...
# 237545    True
# 237568    True
# 237569    True
# 237616    True
# 237643    True
# Name: brand, Length: 14923, dtype: bool

# %%
sales[(sales.category=="Jewellery")&(sales.brand.isnull())]["product_code"].nunique()
# Out:
# 10931

# %% [markdown]
# 7. How many brands have between 35 and 55 transactions (inclusive)?(Just write the numbers)

# %%
final_df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2       pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3       j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4       kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
# ...            ...           ...       ...            ...           ...
# 237666  d7dx6f3qv7           RoW  e2p108mu            RoW  nan9a4p10ayk
# 237667  iaf2ck3rj6            IT  gjb1qntq            RoW  lxj477q1hab2
# 237668  tucgt70cwc            AU  9adnlxvr            RoW  2g0g0obhwjuc
# 237669  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 237670  wnmihth4io            GB  5yogzc17            RoW  wrgq88ujwh5d
#
#                 category             brand currency    price       date  \
# 0                Dresses               NaN      GBP    19.11 2020-08-03
# 1       Outerwear - Mens  Adidas Originals      GBP    24.91 2020-08-03
# 2          Tops - Womens               NaN      GBP    19.31 2020-08-03
# 3       Bottoms - Womens  Urban Outfitters      GBP    16.98 2020-08-03
# 4                  Other               NaN      GBP     2.85 2020-08-03
# ...                  ...               ...      ...      ...        ...
# 237666       Tops - Mens               NaN      PLN     4.24 2020-08-04
# 237667       Accessories               NaN      CZK  3923.18 2020-08-04
# 237668         Jewellery               NaN      PLN   525.82 2020-08-09
# 237669  Bottoms - Womens   Brandy Melville      BRL    34.92 2020-08-06
# 237670  Bottoms - Womens               NaN      NOK   533.06 2020-08-08
#
#             rate  total_sales
# 0        0.89935    21.248680
# 1        0.89935    27.697782
# 2        0.89935    21.471062
# 3        0.89935    18.880302
# 4        0.89935     3.168955
# ...          ...          ...
# 237666   4.39693     0.964309
# 237667  26.12360   150.177617
# 237668   4.41427   119.118223
# 237669   6.33240     5.514497
# 237670  10.64540    50.074210
#
# [237671 rows x 12 columns]

# %%
((final_df["brand"].value_counts() >= 35 ) & (final_df["brand"].value_counts() < 56 )).sum()
# Out:
# 81

# %% [markdown]
# 8. How many pairs of shoes were purchased by Australian (AU) buyers?(Just write the the numbers)

# %%
final_df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2       pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3       j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4       kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
# ...            ...           ...       ...            ...           ...
# 237666  d7dx6f3qv7           RoW  e2p108mu            RoW  nan9a4p10ayk
# 237667  iaf2ck3rj6            IT  gjb1qntq            RoW  lxj477q1hab2
# 237668  tucgt70cwc            AU  9adnlxvr            RoW  2g0g0obhwjuc
# 237669  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 237670  wnmihth4io            GB  5yogzc17            RoW  wrgq88ujwh5d
#
#                 category             brand currency    price       date  \
# 0                Dresses               NaN      GBP    19.11 2020-08-03
# 1       Outerwear - Mens  Adidas Originals      GBP    24.91 2020-08-03
# 2          Tops - Womens               NaN      GBP    19.31 2020-08-03
# 3       Bottoms - Womens  Urban Outfitters      GBP    16.98 2020-08-03
# 4                  Other               NaN      GBP     2.85 2020-08-03
# ...                  ...               ...      ...      ...        ...
# 237666       Tops - Mens               NaN      PLN     4.24 2020-08-04
# 237667       Accessories               NaN      CZK  3923.18 2020-08-04
# 237668         Jewellery               NaN      PLN   525.82 2020-08-09
# 237669  Bottoms - Womens   Brandy Melville      BRL    34.92 2020-08-06
# 237670  Bottoms - Womens               NaN      NOK   533.06 2020-08-08
#
#             rate  total_sales
# 0        0.89935    21.248680
# 1        0.89935    27.697782
# 2        0.89935    21.471062
# 3        0.89935    18.880302
# 4        0.89935     3.168955
# ...          ...          ...
# 237666   4.39693     0.964309
# 237667  26.12360   150.177617
# 237668   4.41427   119.118223
# 237669   6.33240     5.514497
# 237670  10.64540    50.074210
#
# [237671 rows x 12 columns]

# %%
final_df.category.unique()
# Out:
# array(['Dresses', 'Outerwear - Mens', 'Tops - Womens', 'Bottoms - Womens',
#        'Other', 'Accessories', 'Jewellery', 'Home', 'Music', 'Shoes',
#        'Tops - Mens', 'Beauty', 'Bottoms - Mens', 'Art', 'Lingerie',
#        'Outerwear', 'Tech', 'Sports equipment', 'Books & magazines',
#        'Kids', 'Underwear', 'Transportation', 'Film', nan, 'UNSPECIFIED'],
#       dtype=object)

# %%
((final_df.buyer_country == "AU") & (final_df.category == "Shoes" )).sum()
# Out:
# 658

# %%
sales[sales["buyer_country"] == "AU"].groupby("category").size().reset_index(name="count")

# %%
(sales[sales["buyer_country"] == "AU"].groupby("category").size().reset_index(name="count").sort_values(by="count", ascending=False)).loc[16]
# Out:
# category    Shoes
# count         658
# Name: 16, dtype: object

# %% [markdown]
# 9. Which brand has the highest average transaction value? (Just write down the brand as in the dataset, your answer is supposed to be case sensitive)

# %%
final_df.groupby("brand")["price"].mean().sort_values(ascending=False).head(1)
# Out:
# brand
# Goyard    339.363333
# Name: price, dtype: float64

# %%
final_df.groupby("brand")["price"].mean().nlargest(1)
# Out:
# brand
# Goyard    339.363333
# Name: price, dtype: float64

# %%
final_df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       rd209r8c7c            GB  9p2ansc9             GB  wpxxf59cq7pc
# 2       pqbcrl8azx            GB  r9zmzem8             GB  ua9mmn86wsqy
# 3       j5en1rwmxp            GB  3o2nz88r             GB  tduo2uy8iszl
# 4       kjdezxeh1l            GB  7g56ublf             GB  39o00tcu89zq
# ...            ...           ...       ...            ...           ...
# 237666  d7dx6f3qv7           RoW  e2p108mu            RoW  nan9a4p10ayk
# 237667  iaf2ck3rj6            IT  gjb1qntq            RoW  lxj477q1hab2
# 237668  tucgt70cwc            AU  9adnlxvr            RoW  2g0g0obhwjuc
# 237669  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 237670  wnmihth4io            GB  5yogzc17            RoW  wrgq88ujwh5d
#
#                 category             brand currency    price       date  \
# 0                Dresses               NaN      GBP    19.11 2020-08-03
# 1       Outerwear - Mens  Adidas Originals      GBP    24.91 2020-08-03
# 2          Tops - Womens               NaN      GBP    19.31 2020-08-03
# 3       Bottoms - Womens  Urban Outfitters      GBP    16.98 2020-08-03
# 4                  Other               NaN      GBP     2.85 2020-08-03
# ...                  ...               ...      ...      ...        ...
# 237666       Tops - Mens               NaN      PLN     4.24 2020-08-04
# 237667       Accessories               NaN      CZK  3923.18 2020-08-04
# 237668         Jewellery               NaN      PLN   525.82 2020-08-09
# 237669  Bottoms - Womens   Brandy Melville      BRL    34.92 2020-08-06
# 237670  Bottoms - Womens               NaN      NOK   533.06 2020-08-08
#
#             rate  total_sales
# 0        0.89935    21.248680
# 1        0.89935    27.697782
# 2        0.89935    21.471062
# 3        0.89935    18.880302
# 4        0.89935     3.168955
# ...          ...          ...
# 237666   4.39693     0.964309
# 237667  26.12360   150.177617
# 237668   4.41427   119.118223
# 237669   6.33240     5.514497
# 237670  10.64540    50.074210
#
# [237671 rows x 12 columns]

# %% [markdown]
# 10. What is the total value of items purchased by GB buyers from GB sellers? (Just write the numbers in the format of 0.000.000 )

# %%
final_df[(final_df.buyer_country == "GB") & (final_df.seller_country == "GB")]["total_sales"].sum()
# Out:
# 3526745.033129233

# %% [markdown]
# 11. What percentage of US sellers' transactions were purchased by US buyers? (Just write the percentage in the format of 00.00%)

# %%
a = final_df[(final_df.buyer_country == "US") & (final_df.seller_country == "US")]["total_sales"].sum()
a
# Out:
# 2021779.311517296

# %%
b = final_df[(final_df.seller_country == "US")]["total_sales"].sum()
b
# Out:
# 2106695.5606899997

# %%
(a / b) * 100
# Out:
# 95.96922067159569

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 18.1+ MB

# %%
len(sales.columns)
# Out:
# 10

# %%
sales.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date
# 0           Dresses               NaN      GBP  19.11 2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92 2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37 2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27 2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90 2020-08-09
